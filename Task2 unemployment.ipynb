# %% [markdown]
# ![Logo.jpg](attachment:Logo.jpg)

# %% [markdown]
# # Oasis infobye Internship, February - 2024
#
# ### BOTTU BHAVAN, Data Science Intern

# %% [markdown]
# ### Dataset Link - https://www.kaggle.com/datasets/gokulrajkmv/unemployment-in-india/code

# %% [markdown]
# ## Introduction:
#
# The Covid-19 pandemic has not only posed significant challenges to public health but has also triggered widespread economic disruptions globally. One of the prominent indicators reflecting these economic challenges is the unemployment rate, a crucial metric that measures the proportion of unemployed individuals in the total labor force. As businesses faced closures, restrictions, and economic uncertainties, the workforce experienced unprecedented shifts leading to a sharp increase in the unemployment rate.
#
# Understanding and analyzing the dynamics of the unemployment rate during the Covid-19 pandemic can offer valuable insights into the socio-economic impact of the crisis. This data science project aims to explore and dissect the patterns, trends, and factors influencing the unemployment rate, shedding light on the multifaceted consequences of the pandemic on the job market.
#
# ## Key Objectives:
#
# ### Examine Temporal Trends:
# Investigate how the unemployment rate evolved over different phases of the Covid-19 pandemic. Identify critical time points, spikes, and downturns, correlating them with major events or policy changes.
#
# ### Demographic Analysis:
# Break down the unemployment data based on demographics such as age, gender, education level, and industry. Explore whether certain demographic groups were disproportionately affected.
#
# ### Geographical Patterns:
# Analyze regional variations in the unemployment rate. Investigate whether certain areas experienced more severe economic repercussions and if there were disparities in recovery rates.
#
# ### Economic Sectors Impact:
# Assess the impact of the pandemic on specific industries and sectors. Explore which sectors faced the most significant job losses and the potential reasons behind these trends.
#
# ### Government Interventions:
# Investigate the effectiveness of government interventions, such as stimulus packages or employment support programs, in mitigating the rise in unemployment.
#
# ### Predictive Modeling:
# Develop predictive models to forecast potential future unemployment rates based on current economic indicators. Evaluate the accuracy of these models and assess their utility in guiding policy decisions.
#
# ### Policy Implications:
# Provide recommendations for policymakers based on the findings. Suggest potential strategies for addressing the ongoing and future challenges in the job market.
#
# By delving into the complexities of the unemployment rate during the Covid-19 pandemic, this data science project aims to contribute valuable insights that can inform policy decisions, aid economic recovery efforts, and deepen our understanding of the broader societal impact of such crises.

# %% [markdown]
# # Data Exploration and Cleaning:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import calendar

import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
df=pd.read_csv("Task2.csv")
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-01-2020          M                              5.48
# 1    Andhra Pradesh   29-02-2020          M                              5.83
# 2    Andhra Pradesh   31-03-2020          M                              5.79
# 3    Andhra Pradesh   30-04-2020          M                             20.51
# 4    Andhra Pradesh   31-05-2020          M                             17.43
# ..              ...          ...        ...                               ...
# 262     West Bengal   30-06-2020          M                              7.29
# 263     West Bengal   31-07-2020          M                              6.83
# 264     West Bengal   31-08-2020          M                             14.87
# 265     West Bengal   30-09-2020          M                              9.35
# 266     West Bengal   31-10-2020          M                              9.98
#
# ...

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    267 non-null    object
#  1    Date                                     267 non-null    object
#  2    Frequency                                267 non-null    object
#  3    Estimated Unemployment Rate (%)          267 non-null    float64
#  4    Estimated Employed                       267 non-null    int64
#  5    Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                  267 non-null    object
#  7   longitude                                 267 non-null    float64
#  8   latitude                                  267 non-null    float64
# dtypes: float64(4), int64(1), object(4)
# memory usage: 18.9+ KB

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Region.1                                    0
# longitude                                   0
# latitude                                    0
# dtype: int64

# %%
df.shape
# Out:
# (267, 9)

# %%
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude'],
#       dtype='object')

# %%
df.columns = ['States', 'Date', 'Frequency', 'Estimated Unemployment Rate', 'Estimated Employed',
              'Estimated Labour Participation Rate', 'Region', 'longitude', 'latitude']

# %%
# Converting 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)

# %%
# Converting 'Frequency' and 'Region' columns to categorical data type
df['Frequency'] = df['Frequency'].astype('category')
df['Region'] = df['Region'].astype('category')

# %%
# Extracting month from 'Date' and creating a 'Month' column
df['Month'] = df['Date'].dt.month

# %%
# Converting 'Month' to integer format
df['Month_int'] = df['Month'].apply(lambda x: int(x))

# %%
# Mapping integer month values to abbreviated month names
df['Month_name'] = df['Month_int'].apply(lambda x: calendar.month_abbr[x])

# %%
# Dropping the original 'Month' column
df.drop(columns='Month', inplace=True)

# %%
df.head()
# Out:
#            States       Date Frequency  Estimated Unemployment Rate  \
# 0  Andhra Pradesh 2020-01-31         M                         5.48
# 1  Andhra Pradesh 2020-02-29         M                         5.83
# 2  Andhra Pradesh 2020-03-31         M                         5.79
# 3  Andhra Pradesh 2020-04-30         M                        20.51
# 4  Andhra Pradesh 2020-05-31         M                        17.43
#
#    Estimated Employed  Estimated Labour Participation Rate Region  longitude  \
# 0            16635535                                41.02  South    15.9129
# 1            16545652                                40.90  South    15.9129
# 2            15881197                                39.18  South    15.9129
# 3            11336911                                33.10  South    15.9129
# 4            12988845                                36.46  South    15.9129
#
#    latitude  Month_int Month_name
# 0     79.74          1        Jan
# ...

# %% [markdown]
# # Descriptive Statistics:

# %%
df_stats = df[['Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate']]
round(df_stats.describe().T, 2)
# Out:
#                                      count         mean          std  \
# Estimated Unemployment Rate          267.0        12.24        10.80
# Estimated Employed                   267.0  13962105.72  13366318.36
# Estimated Labour Participation Rate  267.0        41.68         7.85
#
#                                            min         25%         50%  \
# Estimated Unemployment Rate               0.50        4.84        9.65
# Estimated Employed                   117542.00  2838930.50  9732417.00
# Estimated Labour Participation Rate      16.77       37.26       40.39
#
#                                              75%          max
# Estimated Unemployment Rate                16.76        75.85
# Estimated Employed                   21878686.00  59433759.00
# Estimated Labour Participation Rate        44.06        69.69

# %%
df_stats = df[['Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate']]
round(df_stats.describe().T, 2)
# Out:
#                                      count         mean          std  \
# Estimated Unemployment Rate          267.0        12.24        10.80
# Estimated Employed                   267.0  13962105.72  13366318.36
# Estimated Labour Participation Rate  267.0        41.68         7.85
#
#                                            min         25%         50%  \
# Estimated Unemployment Rate               0.50        4.84        9.65
# Estimated Employed                   117542.00  2838930.50  9732417.00
# Estimated Labour Participation Rate      16.77       37.26       40.39
#
#                                              75%          max
# Estimated Unemployment Rate                16.76        75.85
# Estimated Employed                   21878686.00  59433759.00
# Estimated Labour Participation Rate        44.06        69.69

# %%
region_stats = df.groupby(['Region'])[['Estimated Unemployment Rate', 'Estimated Employed', 
                                       'Estimated Labour Participation Rate']].mean().reset_index()
round(region_stats, 2)
# Out:
#       Region  Estimated Unemployment Rate  Estimated Employed  \
# 0       East                        13.92         19602366.90
# 1      North                        15.89         13072487.92
# 2  Northeast                        10.95          3617105.53
# 3      South                        10.45         14040589.33
# 4       West                         8.24         18623512.72
#
#    Estimated Labour Participation Rate
# 0                                40.11
# 1                                38.70
# 2                                52.06
# 3                                40.44
# 4                                41.26

# %% [markdown]
# # Correlation Analysis:

# %%
# Correlation Heatmap
heat_maps = df[['Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate', 'longitude', 'latitude', 'Month_int']]
heat_maps = heat_maps.corr()
plt.figure(figsize=(9, 5))
sns.set_context('notebook', font_scale=1)
sns.heatmap(heat_maps, annot=True, cmap='hot')
plt.show()

# %% [markdown]
# # Data Visualization

# %%
# The unemployment rate according to different regions of India:
plt.figure(figsize=(10, 8))
plt.title("Indian Unemployment")
sns.histplot(x="Estimated Unemployment Rate", hue="Region", data=df,palette="Set2")
plt.show()

# %%
import plotly.express as px
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
fig = px.box(df, x='States', y='Estimated Unemployment Rate', color='States', title='Unemployment Rate Per States', template='plotly')
fig.show()
# Out:
# <div>                            <div id="d149be35-4441-4ce1-a0d5-711af61e0257" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d149be35-4441-4ce1-a0d5-711af61e0257")) {                    Plotly.newPlot(                        "d149be35-4441-4ce1-a0d5-711af61e0257",                        [{"alignmentgroup":"True","hovertemplate":"States=%{x}<br>Estimated Unemployment Rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa"},"name":"Andhra Pradesh","notched":false,"offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"x":["Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh","Andhra Pradesh"],"x0":" ","xaxis":"
# ...

# %%
# Scatter matrix

fig = px.scatter_matrix(df, template='plotly',
                        dimensions=['Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate'],
                        color='Region', color_discrete_sequence=['red', 'blue', 'green'],width=900, height=700)
fig.show()
fig.show()
# Out:
# <div>                            <div id="3959648b-e593-48aa-a666-89ae5c81d0db" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3959648b-e593-48aa-a666-89ae5c81d0db")) {                    Plotly.newPlot(                        "3959648b-e593-48aa-a666-89ae5c81d0db",                        [{"dimensions":[{"axis":{"matches":true},"label":"Estimated Unemployment Rate","values":[5.48,5.83,5.79,20.51,17.43,3.31,8.34,6.96,6.4,6.59,2.86,3.61,3.46,29.84,19.97,8.44,4.01,0.5,2.41,1.58,5.31,7.6,8.99,16.99,17.88,9.71,7.09,10.98,5.91,3.88,0.58,1.76,1.2,75.85,58.19,4.24,15.47,5.05,10.9,6.18,1.57,2.09,6.4,49.83,33.16,12.2,6.81,2.65,5.0,2.16,5.49,8.29,5.77,6.25,14.7,10.55,5.36,5.79,3.27,2.86]},{"axis":{"matches":true},"label":"Estimated Employed","values":[16635
# ...

# %%
# Selecting relevant columns and grouping by state to calculate the average unemployment rate
plot_ump = df[['Estimated Unemployment Rate', 'States']]
df_unemp = plot_ump.groupby('States').mean().reset_index()

# Sorting the DataFrame by the average unemployment rate
df_unemp = df_unemp.sort_values('Estimated Unemployment Rate')

# Creating a bar plot using Plotly Express
fig = px.bar(df_unemp, x='States', y='Estimated Unemployment Rate', color='States',
             title='Average Unemployment Rate in each state', template='plotly')
fig.show()
# Out:
# <div>                            <div id="d064bf02-6bc8-40c1-ab80-cb682d68538f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d064bf02-6bc8-40c1-ab80-cb682d68538f")) {                    Plotly.newPlot(                        "d064bf02-6bc8-40c1-ab80-cb682d68538f",                        [{"alignmentgroup":"True","hovertemplate":"States=%{x}<br>Estimated Unemployment Rate=%{y}<extra></extra>","legendgroup":"Meghalaya","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Meghalaya","offsetgroup":"Meghalaya","orientation":"v","showlegend":true,"textposition":"auto","x":["Meghalaya"],"xaxis":"x","y":[3.8659999999999997],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=%{x}<br>Estimated Unemployment Rate=%{y}<extra></e
# ...

# %%
# Animated bar plot of Unemployment rate across region from Jan.2020 to Oct.2020

fig = px.bar(df, x='Region', y='Estimated Unemployment Rate', animation_frame='Month_name', color='States',
             title='Unemployment rate across region from Jan.2020 to Oct.2020', height=700, template='plotly')
fig.update_layout(xaxis={'categoryorder': 'total descending'})
fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 2000
fig.show()
# Out:
# <div>                            <div id="7253fdc2-98c3-4b70-a9e3-692d0c0cbbcb" class="plotly-graph-div" style="height:700px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7253fdc2-98c3-4b70-a9e3-692d0c0cbbcb")) {                    Plotly.newPlot(                        "7253fdc2-98c3-4b70-a9e3-692d0c0cbbcb",                        [{"alignmentgroup":"True","hovertemplate":"States=Andhra Pradesh<br>Month_name=Jan<br>Region=%{x}<br>Estimated Unemployment Rate=%{y}<extra></extra>","legendgroup":"Andhra Pradesh","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Andhra Pradesh","offsetgroup":"Andhra Pradesh","orientation":"v","showlegend":true,"textposition":"auto","x":["South"],"xaxis":"x","y":[5.48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"States=Assam<br>M
# ...

# %%
# Sunburst chart showing unemployment rate in each region and state

unemplo_df = df[['States', 'Region', 'Estimated Unemployment Rate', 'Estimated Employed', 'Estimated Labour Participation Rate']]
unemplo = unemplo_df.groupby(['Region', 'States'])['Estimated Unemployment Rate'].mean().reset_index()
fig = px.sunburst(unemplo, path=['Region', 'States'], values='Estimated Unemployment Rate',
                  color_continuous_scale='Plasma', title='Unemployment rate in each region and state',
                  height=650, template='ggplot2')
fig.show()
# Out:
# <div>                            <div id="a9642d6e-d628-4edc-a222-d6b972a525f3" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a9642d6e-d628-4edc-a222-d6b972a525f3")) {                    Plotly.newPlot(                        "a9642d6e-d628-4edc-a222-d6b972a525f3",                        [{"branchvalues":"total","domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"labels=%{label}<br>Estimated Unemployment Rate=%{value}<br>parent=%{parent}<br>id=%{id}<extra></extra>","ids":["East/Andhra Pradesh","North/Andhra Pradesh","Northeast/Andhra Pradesh","South/Andhra Pradesh","West/Andhra Pradesh","East/Assam","North/Assam","Northeast/Assam","South/Assam","West/Assam","East/Bihar","North/Bihar","Northeast/Bihar","South/Bihar","West/Bihar","East/Chhattisg
# ...

# %%
fig = px.scatter_geo(df,'longitude', 'latitude', color="Region",
                     hover_name="States", size="Estimated Unemployment Rate",
                     animation_frame="Month_name",scope='asia',template='seaborn',title='Impack of lockdown on Employement across regions')

fig.layout.updatemenus[0].buttons[0].args[1]["frame"]["duration"] = 3000

fig.update_geos(lataxis_range=[5,35], lonaxis_range=[65, 100],oceancolor="#3399FF",
    showocean=True)

fig.show()
# Out:
# <div>                            <div id="8d6adfaf-35fc-4cdc-bde7-2fb326ebf36b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8d6adfaf-35fc-4cdc-bde7-2fb326ebf36b")) {                    Plotly.newPlot(                        "8d6adfaf-35fc-4cdc-bde7-2fb326ebf36b",                        [{"geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>Region=South<br>Month_name=Jan<br>Estimated Unemployment Rate=%{marker.size}<br>longitude=%{lat}<br>latitude=%{lon}<extra></extra>","hovertext":["Andhra Pradesh","Karnataka","Kerala","Puducherry","Tamil Nadu","Telangana"],"lat":[15.9129,15.3173,10.8505,11.9416,11.1271,18.1124],"legendgroup":"South","lon":[79.74,75.7139,76.2711,79.8083,78.6569,79.0193],"marker":{"color":"rgb(76,114,176)","size":[5.48,2.86,5.
# ...

# %%
#data representation before and after the lockdown
after_lockdown = df[(df['Month_int'] >= 4) & (df['Month_int'] <=6)]
before_lockdown = df[(df['Month_int'] >= 1) & (df['Month_int'] <=4)]

# %%
af_lockdown=after_lockdown.groupby('States')['Estimated Unemployment Rate'].mean().reset_index()
lockdown= before_lockdown.groupby('States')['Estimated Unemployment Rate'].mean().reset_index()
lockdown['Unemployment Rate before lockdown'] = af_lockdown['Estimated Unemployment Rate']

lockdown.columns=['States','Unemployment Rate Before Lockdown','Unemployment Rate After Lockdown']
lockdown.head()
# Out:
#            States  Unemployment Rate Before Lockdown  \
# 0  Andhra Pradesh                             9.4025
# 1           Assam                             6.2250
# 2           Bihar                            20.7425
# 3    Chhattisgarh                             7.2450
# 4           Delhi                            17.6975
#
#    Unemployment Rate After Lockdown
# 0                         13.750000
# 1                          7.070000
# 2                         36.806667
# 3                          9.380000
# 4                         25.713333

# %%
# percentage change in unemployment rate

lockdown['rate change in unemployment'] = round(lockdown['Unemployment Rate After Lockdown'] -lockdown['Unemployment Rate Before Lockdown']/lockdown['Unemployment Rate Before Lockdown'],2)
plot_per = lockdown.sort_values('rate change in unemployment')

# %%
# percentage change in unemployment after lockdown

fig = px.bar(plot_per, x='States',y='rate change in unemployment',color='rate change in unemployment',
            title='percentage change in Unemployment in each state after lockdown',template='ggplot2')
fig.show()
# Out:
# <div>                            <div id="0925f960-bab2-4942-8e5f-41305c487250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0925f960-bab2-4942-8e5f-41305c487250")) {                    Plotly.newPlot(                        "0925f960-bab2-4942-8e5f-41305c487250",                        [{"alignmentgroup":"True","hovertemplate":"States=%{x}<br>rate change in unemployment=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[4.7,6.07,6.7,8.38,9.42,9.5,10.34,11.98,12.61,12.75,13.04,13.21,13.84,13.86,14.2,14.91,14.94,16.14,17.33,18.42,24.71,27.15,30.73,31.98,35.81,41.42,45.09],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Meghalaya","Assam","U
# ...

# %%
# function to sort value based on impact

def sort_impact(x):
    if x <= 10:
        return 'impacted States'
    elif x <= 20:
        return 'hard impacted States'
    elif x <= 30:
        return 'harder impacted States'
    elif x <= 46:
        return 'hardest impacted States'
    return x

# %%
plot_per['impact status'] = plot_per['rate change in unemployment'].apply(lambda x:sort_impact(x))

# %%
fig = px.bar(plot_per, y='States',x='rate change in unemployment',color='impact status',
            title='Impact of lockdown on employment across states',template='ggplot2',height=650)


fig.show()
# Out:
# <div>                            <div id="6be733c2-11d7-4d7f-b51f-1c2fb0a597bb" class="plotly-graph-div" style="height:650px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6be733c2-11d7-4d7f-b51f-1c2fb0a597bb")) {                    Plotly.newPlot(                        "6be733c2-11d7-4d7f-b51f-1c2fb0a597bb",                        [{"alignmentgroup":"True","hovertemplate":"impact status=impacted States<br>rate change in unemployment=%{x}<br>States=%{y}<extra></extra>","legendgroup":"impacted States","marker":{"color":"#F8766D","pattern":{"shape":""}},"name":"impacted States","offsetgroup":"impacted States","orientation":"h","showlegend":true,"textposition":"auto","x":[4.7,6.07,6.7,8.38,9.42,9.5],"xaxis":"x","y":["Meghalaya","Assam","Uttarakhand","Chhattisgarh","Sikkim","Telangana"],"yaxis":
# ...

# %% [markdown]
# # Conclusion:
#
# The analysis of the unemployment dataset spanning from January 2020 to October 2020 provides valuable insights into the economic impact of the Covid-19 pandemic across different regions in India. Here are the key conclusions drawn from the exploratory data analysis:
#
# ## Regional Disparities:
# The estimated unemployment rate varies significantly across regions. The East region shows the highest average unemployment rate, while the West region exhibits the lowest.
#
#
# ## Temporal Trends:
# The animated bar plot reveals dynamic fluctuations in the unemployment rate across regions from January 2020 to October 2020. This timeline visualization captures the evolving economic landscape during the pandemic.
#
#
# ## Geospatial Impact:
# The geospatial analysis highlights the geographical distribution of unemployment rates, showcasing how states were differently affected. Certain regions experienced more pronounced impacts, visible on the scatter plot overlaid on a map.
#
#
# ## Before and After Lockdown:
# The comparison between unemployment rates before and after the lockdown reveals varying degrees of impact. States like Bihar and Delhi witnessed substantial increases, emphasizing the profound consequences of pandemic-induced restrictions.
#
#
# ## Impact Classification:
# States are categorized based on the percentage change in unemployment rates after the lockdown. This classification provides a nuanced understanding of the severity of economic challenges faced by different regions.
#
#
# ## Recommendations:
# Policymakers can leverage these insights to tailor interventions and support strategies to regions facing the most significant economic downturns. Targeted initiatives aimed at the hardest impacted states may be crucial for effective recovery.
#
#
# ## Continued Monitoring:
# The data analysis underscores the importance of continued monitoring of unemployment trends, considering the dynamic nature of the pandemic. Regular updates and assessments can guide adaptive policies in response to changing economic conditions.
